# %%
# %cd ~
# !wget -q https://ikatago-resources.oss-cn-beijing.aliyuncs.com/all/install.sh -O install.sh
# !chmod +x ./install.sh
# !./install.sh
# Out:
# /root
# System Env:  ubuntu-2004-cuda-11.6
# GPU Info:  Tesla T4 x 1
# USING PACKAGE: ubuntu-20-cuda-11.4-CUDA
# ...
# Download done
# Installing...
# Installing weights...
# Installing engines...
# Installing others...
# /root
# Install Successfully, now you can run the ikatago-server

# %%
USER_NAME="TNTChina"
USER_PASSWORD="1q2w3e4r5t"

PLATFORM_TOKEN="eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.eyJkYXRhRW5jcnlwdEtleVByZWZpeCI6ImxmZHNreCIsImlhdCI6MTYyMjc4ODU4OSwiZXhwIjoxOTQ4NTUwMzk5LCJhdWQiOiJhbGwiLCJpc3MiOiJraW5ma29uZyJ9.0doLI-nXqDlr0w0RRV2sBeEAZhS4mkrBg5YpjwqmnNubgnAulsCK9FrSLgDJGMFSh_lW2XM1SaZWQ6A9-GnsS0t6rY_41_xyJ7eE35MFI3crOkT8eJIMzGapuxpPsNBjPHYB3CgduMZopmoQqLgHNMpXwQE-Ed43wCxU-_zMYJHTyHCf_Anbs0NEo9P8H8ocvLQ5V5GppXmQQa3-PgO9FQP1HiL4iEa0W2F9AH--YE1V6Hd2IoeX_1i4RSzdDB0dGDcjsA59BTxCcHGbnwx30IYaaDfIuGVw7AmFfUR3qQJln3XUTqV_EPezS-xHD1v1-BvNocxvCI9evPe5ftAEDA"
# !sudo apt-get install python3-libnvinfer
# !sudo apt-get install python3-libnvinfer-dev
# %cd ~/work
# !wget https://github.com/TNTChinaAAB/lib/raw/main/libzip.so.4 -O ./data/bins/katago-1.11.0/libzip.so.4
# !wget https://github.com/TNTChinaAAB/lib/raw/main/katago -O ./data/bins/katago-1.11.0/katago
# !wget https://github.com/TNTChinaAAB/lib/raw/main/30b.gz -O ./data/weights/40b.bin.gz
# !echo $USER_NAME":"$USER_PASSWORD > ./userlist.txt
# !chmod +x ./change-frpc.sh 
# !./change-frpc.sh $USER_NAME
# !chmod +x ./ikatago-server
# !./ikatago-server --platform all --token $PLATFORM_TOKEN
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libnvinfer-plugin8 libnvinfer8 libnvonnxparsers8 libnvparsers8
# The following NEW packages will be installed:
#   libnvinfer-plugin8 libnvinfer8 libnvonnxparsers8 libnvparsers8
#   python3-libnvinfer
# 0 upgraded, 5 newly installed, 0 to remove and 23 not upgraded.
# Need to get 291 MB of archives.
# After this operation, 920 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libnvinfer8 8.5.2-1+cuda11.8 [275 MB]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libnvinfer-plugin8 8.5.2-1+cuda11.8 [14.1 MB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  libnvonnxparsers8 8.5.2-1+cuda11.8 [715 kB]
# ...

# %%
# %cd ~
# !wget -q https://ikatago-resources.oss-cn-beijing.aliyuncs.com/all/install_weight.sh -O install_weight.sh
# !chmod +x ./install_weight.sh
# !./install_weight.sh "40b-large" "30b" "20b297" "20b191"
# Out:
# /root
